# %%
##  Exporting library for panda  & numpy
import pandas as pd
import numpy as np

# %%
##  load data frame  from local disk
df = pd.read_csv("C:\\Users\\Sarthak\\Pictures\\RentPrediction - RentPrediction.csv",",")
# Understanding  how many rows & columns 
df.shape
# Out:
# (34226, 14)

# %%
# First five records
df.head(5)
# Out:
#          id                                            name host_name  \
# 0   5728806                    Large private room in Nolita       Nat
# 1   2243769              Super Bowl New York City Apartment     Brian
# 2  35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION     Jenny
# 3  36202006    Stream-Pressed Paradise (Laundry Room Setup)      Rita
# 4   3780951                       Charming Harlem apartment      Gina
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan           Nolita  40.72217  -73.99481     Private room
# 1           Manhattan  Upper West Side  40.80020  -73.96045  Entire home/apt
# 2              Queens    East Elmhurst  40.75558  -73.89316  Entire home/apt
# 3       Staten Island          Concord  40.60110  -74.07830      Shared room
# 4           Manhattan           Harlem  40.81022  -73.94266      Shared room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# Getting column name of data frame and corresponding data type  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34226 entries, 0 to 34225
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              34226 non-null  int64
#  1   name                            34214 non-null  object
#  2   host_name                       34213 non-null  object
#  3   neighbourhood_group             34226 non-null  object
#  4   neighbourhood                   34226 non-null  object
#  5   latitude                        34226 non-null  float64
#  6   longitude                       34226 non-null  float64
#  7   room_type                       34226 non-null  object
#  8   price                           34226 non-null  int64
#  9   minimum_nights                  34226 non-null  int64
#  10  number_of_reviews               34226 non-null  int64
#  11  reviews_per_month               27244 non-null  float64
# ...

# %%
df.describe()
# Describle is very critical function to find one page statistics 
#count - The number of not-empty values.
#mean - The average (mean) value.
#std - The standard deviation.
#min - the minimum value.
#25% - The 25% percentile*.
#50% - The 50% percentile*.
#75% - The 75% percentile*.
#max - the maximum value.
# Out:
#                  id      latitude     longitude         price  minimum_nights  \
# count  3.422600e+04  34226.000000  34226.000000  34226.000000    34226.000000
# mean   1.898209e+07     40.729059    -73.952070    153.480979        6.953690
# std    1.097597e+07      0.054604      0.046161    243.312608       20.255833
# min    2.595000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    9.460366e+06     40.690040    -73.983150     69.000000        1.000000
# 50%    1.965371e+07     40.722995    -73.955700    107.000000        2.000000
# 75%    2.908201e+07     40.763200    -73.935982    175.000000        5.000000
# max    3.648724e+07     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       34226.000000       27244.000000                    34226.000000
# mean           23.390931           1.377074                        7.093905
# ...

# %%
## Unique function on a column
df.neighbourhood_group.unique()
# Out:
# array(['Manhattan', 'Queens', 'Staten Island', 'Brooklyn', 'Bronx'],
#       dtype=object)

# %%
df.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
# Getting NULL values 
df.isnull().sum()
# Out:
# id                                   0
# name                                12
# host_name                           13
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# reviews_per_month                 6982
# calculated_host_listings_count       0
# availability_365                     0
# dtype: int64

# %%
print ( "Data analysis continuation  >>>>")
# Out:
# Data analysis continuation  >>>>

# %%
print("show list of columns used in data frame")
df.columns
# Out:
# show list of columns used in data frame
# Index(['id', 'name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
#Selection os a column
df[['room_type']]
# Out:
#              room_type
# 0         Private room
# 1      Entire home/apt
# 2      Entire home/apt
# 3          Shared room
# 4          Shared room
# ...                ...
# 34221  Entire home/apt
# 34222     Private room
# 34223  Entire home/apt
# 34224     Private room
# 34225  Entire home/apt
#
# [34226 rows x 1 columns]

# %%
#Making a new column - total listings possible - used during feature engineering process
df['total_listings'] = df['availability_365']/df['minimum_nights']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34226 entries, 0 to 34225
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              34226 non-null  int64
#  1   name                            34214 non-null  object
#  2   host_name                       34213 non-null  object
#  3   neighbourhood_group             34226 non-null  object
#  4   neighbourhood                   34226 non-null  object
#  5   latitude                        34226 non-null  float64
#  6   longitude                       34226 non-null  float64
#  7   room_type                       34226 non-null  object
#  8   price                           34226 non-null  int64
#  9   minimum_nights                  34226 non-null  int64
#  10  number_of_reviews               34226 non-null  int64
#  11  reviews_per_month               27244 non-null  float64
# ...

# %%
#Locating a row
df.set_index("name", inplace = True)
df.head(5)
# Out:
#                                                       id host_name  \
# name
# Large private room in Nolita                     5728806       Nat
# Super Bowl New York City Apartment               2243769     Brian
# COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION  35515415     Jenny
# Stream-Pressed Paradise (Laundry Room Setup)    36202006      Rita
# Charming Harlem apartment                        3780951      Gina
#
#                                                neighbourhood_group  \
# name
# Large private room in Nolita                             Manhattan
# Super Bowl New York City Apartment                       Manhattan
# COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION              Queens
# Stream-Pressed Paradise (Laundry Room Setup)         Staten Island
# Charming Harlem apartment                                Manhattan
#
#                                                   neighbourhood  latitude  \
# name
# ...

# %%
df.loc['Large private room in Nolita']
# Out:
# id                                     5728806
# host_name                                  Nat
# neighbourhood_group                  Manhattan
# neighbourhood                           Nolita
# latitude                              40.72217
# longitude                            -73.99481
# room_type                         Private room
# price                                      120
# minimum_nights                               7
# number_of_reviews                            3
# reviews_per_month                         0.06
# calculated_host_listings_count               3
# availability_365                             0
# total_listings                             0.0
# Name: Large private room in Nolita, dtype: object

# %%
df.reset_index("name",drop=True, inplace= True)
df.head(5)

# %%
df.shape
df = pd.read_csv("C:\\Users\\Sarthak\\Pictures\\RentPrediction - RentPrediction.csv",",")
df.shape
df.head(5)
# Out:
#          id                                            name host_name  \
# 0   5728806                    Large private room in Nolita       Nat
# 1   2243769              Super Bowl New York City Apartment     Brian
# 2  35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION     Jenny
# 3  36202006    Stream-Pressed Paradise (Laundry Room Setup)      Rita
# 4   3780951                       Charming Harlem apartment      Gina
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan           Nolita  40.72217  -73.99481     Private room
# 1           Manhattan  Upper West Side  40.80020  -73.96045  Entire home/apt
# 2              Queens    East Elmhurst  40.75558  -73.89316  Entire home/apt
# 3       Staten Island          Concord  40.60110  -74.07830      Shared room
# 4           Manhattan           Harlem  40.81022  -73.94266      Shared room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
df.set_index("host_name", inplace = True)
df.head(5)
# Out:
#                  id                                            name  \
# host_name
# Nat         5728806                    Large private room in Nolita
# Brian       2243769              Super Bowl New York City Apartment
# Jenny      35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION
# Rita       36202006    Stream-Pressed Paradise (Laundry Room Setup)
# Gina        3780951                       Charming Harlem apartment
#
#           neighbourhood_group    neighbourhood  latitude  longitude  \
# host_name
# Nat                 Manhattan           Nolita  40.72217  -73.99481
# Brian               Manhattan  Upper West Side  40.80020  -73.96045
# Jenny                  Queens    East Elmhurst  40.75558  -73.89316
# Rita            Staten Island          Concord  40.60110  -74.07830
# Gina                Manhattan           Harlem  40.81022  -73.94266
#
#                  room_type  price  minimum_nights  number_of_reviews  \
# host_name
# ...

# %%
df.loc[['Rita','Jenny']]
# Out:
#                  id                                               name  \
# host_name
# Rita       36202006       Stream-Pressed Paradise (Laundry Room Setup)
# Rita       35892874  3 Bedroom Loft Like Triplex 2.5 Bath with Garden.
# Rita         788005    Spacious 1 Bedroom Apt, Prospect Hts/Park Slope
# Rita       28927140                            Gentleman's Quarters #2
# Rita       26332143           Bayridge Clean, Beautiful, Spacious Room
# Rita       22224945   IL TUO APPARTAMENTO PERSONALE IN NEW YORK CITY!!
# Rita       29706277    Vintage first floor private room in a 3 bed apt
# Rita       28400092               Private Bedroom Minutes To Manhattan
# Rita       29689253  Privet Room in GROUND FLOOR apt with FREE parking
# Rita       33243529      Astoria Bedroom 20 minutes away from the city
# Rita       10502523  Private Room For 1 w/ Separate Entrance Studen...
# Rita       28927290                               Gentleman's Quarters
# ...

# %%
#Locate using row number
df.iloc[1]
# Out:
# id                                                           2243769
# name                              Super Bowl New York City Apartment
# neighbourhood_group                                        Manhattan
# neighbourhood                                        Upper West Side
# latitude                                                     40.8002
# longitude                                                  -73.96045
# room_type                                            Entire home/apt
# price                                                           1500
# minimum_nights                                                     1
# number_of_reviews                                                  0
# reviews_per_month                                                NaN
# calculated_host_listings_count                                     1
# availability_365                                                   0
# Name: Brian, dtype: object

# %%
#Function to find total values in each category
df['neighbourhood_group'].value_counts()
# Out:
# Manhattan        15193
# Brooklyn         14033
# Queens            3985
# Bronx              767
# Staten Island      248
# Name: neighbourhood_group, dtype: int64

# %%
#Conditional filtering - view only the data from Bronx neighbourhood group
Staten_Island = df[df['neighbourhood_group'] == 'Staten Island']
print(Staten_Island)
# Out:
#                  id                                             name  \
# host_name
# Rita       36202006     Stream-Pressed Paradise (Laundry Room Setup)
# Vadim        644575                 Enjoy and discover New York Citi
# Alex        9767864                          Owl's Landing- The Loft
# Kevin      17735156         Private Cozy Large  Comfortable Bedroom.
# Wj         24019172        XL Ensuite 5m to Ferry, RUMC, Snug Harbor
# ...             ...                                              ...
# Faye       18414310     Cozy Room Easy Access To Manhattan - Room #3
# Marina       639199  Beautiful 4BR/4BA Home, Staten Island, NY City.
# Tricia     16883129                 Charming Studio In Historic Home
# Mimi       20676841      Private room 15 MINS AWAY FROM FERRY by bus
# Jason      34255438                                   NYC Lux. Condo
#
#           neighbourhood_group    neighbourhood  latitude  longitude  \
# host_name
# ...

# %%
df.head(5)

# %%
df['neighbourhood_group'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
seaborn.set(style = 'whitegrid')
seaborn.scatterplot(x ="availability_365", y ="price",data = df)
# Out:
# <AxesSubplot:xlabel='availability_365', ylabel='price'>

# %%
sns.catplot(data=df, x="neighbourhood_group", y="price", kind="box")

# %%
sns.catplot(data=df.query('price < 1600'), x="neighbourhood_group", y="price",hue="room_type", kind="boxen"  )

# %%
sns.barplot(x="neighbourhood_group", y="price", hue="room_type", data=df.query('price < 1600'));
